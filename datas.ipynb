# %% [markdown]
# <a href="https://colab.research.google.com/github/eduardagoulart/pandas_study/blob/master/datas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Looking inside the Dataframe: columns, rows and cells

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/sample_data/california_housing_train.csv")

# %% [markdown]
# ### How we can look at the value for one column?

# %%
df.longitude
# Out:
# 0       -114.31
# 1       -114.47
# 2       -114.56
# 3       -114.57
# 4       -114.57
#           ...
# 16995   -124.26
# 16996   -124.27
# 16997   -124.30
# 16998   -124.30
# 16999   -124.35
# Name: longitude, Length: 17000, dtype: float64

# %%
df["longitude"]
# Out:
# 0       -114.31
# 1       -114.47
# 2       -114.56
# 3       -114.57
# 4       -114.57
#           ...
# 16995   -124.26
# 16996   -124.27
# 16997   -124.30
# 16998   -124.30
# 16999   -124.35
# Name: longitude, Length: 17000, dtype: float64

# %% [markdown]
# as we can see, both ways work when you want to access the information in one column. We can access them similar as a dictionary or even as an attibute

# %% [markdown]
# ### Access information on a Dataframe

# %%
df.head(10)
# show the first 10 elements
# Out:
#    longitude  latitude  ...  median_income  median_house_value
# 0    -114.31     34.19  ...         1.4936             66900.0
# 1    -114.47     34.40  ...         1.8200             80100.0
# 2    -114.56     33.69  ...         1.6509             85700.0
# 3    -114.57     33.64  ...         3.1917             73400.0
# 4    -114.57     33.57  ...         1.9250             65500.0
# 5    -114.58     33.63  ...         3.3438             74000.0
# 6    -114.58     33.61  ...         2.6768             82400.0
# 7    -114.59     34.83  ...         1.7083             48500.0
# 8    -114.59     33.61  ...         2.1782             58400.0
# 9    -114.60     34.83  ...         2.1908             48100.0
#
# [10 rows x 9 columns]

# %%
df.tail(10)
# show the last 10 elements
# Out:
#        longitude  latitude  ...  median_income  median_house_value
# 16990    -124.22     41.73  ...         1.7038             78300.0
# 16991    -124.23     41.75  ...         2.4805             73200.0
# 16992    -124.23     40.81  ...         3.3462             50800.0
# 16993    -124.23     40.54  ...         3.0806            106700.0
# 16994    -124.25     40.28  ...         1.9417             76100.0
# 16995    -124.26     40.58  ...         2.3571            111400.0
# 16996    -124.27     40.69  ...         2.5179             79000.0
# 16997    -124.30     41.84  ...         3.0313            103600.0
# 16998    -124.30     41.80  ...         1.9797             85800.0
# 16999    -124.35     40.54  ...         3.0147             94600.0
#
# [10 rows x 9 columns]

# %%
df.sample(10)
# pick 10 random elements
# Out:
#        longitude  latitude  ...  median_income  median_house_value
# 2380     -117.53     33.97  ...         3.8906            141000.0
# 3437     -117.89     33.87  ...         3.0893            188200.0
# 1404     -117.18     33.51  ...         6.9930            500001.0
# 8970     -118.92     36.04  ...         2.9208             98500.0
# 15274    -122.28     37.88  ...         3.0060            227900.0
# 237      -116.50     33.95  ...         1.6983             66600.0
# 10152    -119.83     34.44  ...         3.0875            198400.0
# 9770     -119.67     36.83  ...         4.4356            111300.0
# 8860     -118.75     34.28  ...         6.2059            239900.0
# 4572     -118.06     34.16  ...         3.6705            286500.0
#
# [10 rows x 9 columns]

# %% [markdown]
# ### How can I access more then one column at the same time?

# %%
df[["longitude", "latitude"]]
# Out:
#        longitude  latitude
# 0        -114.31     34.19
# 1        -114.47     34.40
# 2        -114.56     33.69
# 3        -114.57     33.64
# 4        -114.57     33.57
# ...          ...       ...
# 16995    -124.26     40.58
# 16996    -124.27     40.69
# 16997    -124.30     41.84
# 16998    -124.30     41.80
# 16999    -124.35     40.54
#
# [17000 rows x 2 columns]

# %% [markdown]
# to pick multiple columns we need to use two brackets. This can take more time, since we are doing a copy of the original dataframe, but only with the selected columns.
#
# At the example bellow, *new_df* is another dataframe, that contains information about *total rooms* and *house holds*

# %%
new_df = df[["households", "total_rooms"]]
new_df
# Out:
#        households  total_rooms
# 0           472.0       5612.0
# 1           463.0       7650.0
# 2           117.0        720.0
# 3           226.0       1501.0
# 4           262.0       1454.0
# ...           ...          ...
# 16995       369.0       2217.0
# 16996       465.0       2349.0
# 16997       456.0       2677.0
# 16998       478.0       2672.0
# 16999       270.0       1820.0
#
# [17000 rows x 2 columns]

# %% [markdown]
# # Subsetting information

# %% [markdown]
# loc: based on index label (row name)
#
# iloc: based on row index (row number)

# %% [markdown]
# ## Loc function

# %%
df.loc[0]
# information from the first row
# Out:
# longitude              -114.3100
# latitude                 34.1900
# housing_median_age       15.0000
# total_rooms            5612.0000
# total_bedrooms         1283.0000
# population             1015.0000
# households              472.0000
# median_income             1.4936
# median_house_value    66900.0000
# Name: 0, dtype: float64

# %%
df.loc[99]
# information from the row with index 99
# Out:
# longitude              -115.590
# latitude                 32.850
# housing_median_age       20.000
# total_rooms            1608.000
# total_bedrooms          274.000
# population              862.000
# households              248.000
# median_income             4.875
# median_house_value    90800.000
# Name: 99, dtype: float64

# %% [markdown]
# I wanna access the last row, how can I do this?

# %%
number_of_rows = df.shape[0]
df.loc[number_of_rows - 1] # index start with 0, so to access the actual number 
# we need to subtract 1
# Out:
# longitude              -124.3500
# latitude                 40.5400
# housing_median_age       52.0000
# total_rooms            1820.0000
# total_bedrooms          300.0000
# population              806.0000
# households              270.0000
# median_income             3.0147
# median_house_value    94600.0000
# Name: 16999, dtype: float64

# %%
# or using tail 
df.tail(n=1)
# Out:
#        longitude  latitude  ...  median_income  median_house_value
# 16999    -124.35     40.54  ...         3.0147             94600.0
#
# [1 rows x 9 columns]

# %% [markdown]
# we can see that loc and tail function returned two different formats. The reason for that is, when we use loc we have a new Serie created with all information for that position. However, using tail, we are filtering one row for the DataFrame, and that will continue be trated as a DF.

# %% [markdown]
# ### Subsetting multiple rows

# %%
df.loc[[0, 99, 1000]]
# Out:
#       longitude  latitude  ...  median_income  median_house_value
# 0       -114.31     34.19  ...         1.4936             66900.0
# 99      -115.59     32.85  ...         4.8750             90800.0
# 1000    -117.10     33.36  ...         3.2614            168800.0
#
# [3 rows x 9 columns]

# %%
new_loc_df = df.loc[[0, 99, 1000]]
new_loc_df
# Out:
#       longitude  latitude  ...  median_income  median_house_value
# 0       -114.31     34.19  ...         1.4936             66900.0
# 99      -115.59     32.85  ...         4.8750             90800.0
# 1000    -117.10     33.36  ...         3.2614            168800.0
#
# [3 rows x 9 columns]

# %% [markdown]
# Keep in mind that this method will take longer to finish, because we are actually creating a copy of the original dataframe, but only with the selected information (copy process are a little bit slow in Pandas)

# %% [markdown]
# ## iloc function

# %% [markdown]
# iloc function works the same as loc, but takes the row index number (each row index can have different name, iloc will take the number no matter the name that uses)

# %%
df.iloc[1]
# takes the second row
# Out:
# longitude              -114.47
# latitude                 34.40
# housing_median_age       19.00
# total_rooms            7650.00
# total_bedrooms         1901.00
# population             1129.00
# households              463.00
# median_income             1.82
# median_house_value    80100.00
# Name: 1, dtype: float64

# %%
# curiosity: to access the last row, we don't need to use any Python tools
# it can be donne only with pandas and the index -1
df.iloc[-1]
# Out:
# longitude              -124.3500
# latitude                 40.5400
# housing_median_age       52.0000
# total_rooms            1820.0000
# total_bedrooms          300.0000
# population              806.0000
# households              270.0000
# median_income             3.0147
# median_house_value    94600.0000
# Name: 16999, dtype: float64

# %% [markdown]
# # Subsetting colums
#
# how we use loc and iloc to filter coluns

# %%
subset = df.loc[:, ["longitude", "total_rooms"]]
# we got all the rows from df at columnd longitude and total_rooms
subset.head()
# Out:
#    longitude  total_rooms
# 0    -114.31       5612.0
# 1    -114.47       7650.0
# 2    -114.56        720.0
# 3    -114.57       1501.0
# 4    -114.57       1454.0

# %%
iloc_subset = df.iloc[:, [2, 4, -1]]
# using iloc, we can pass the columns number
# in this case, we create a new df with all the rows for columns: 2, 4 and the 
# last one
iloc_subset.head()
# Out:
#    housing_median_age  total_bedrooms  median_house_value
# 0                15.0          1283.0             66900.0
# 1                19.0          1901.0             80100.0
# 2                17.0           174.0             85700.0
# 3                14.0           337.0             73400.0
# 4                20.0           326.0             65500.0

# %% [markdown]
# ## Subsetting by range

# %% [markdown]
# we will use a Python function to create a range of values. This way, we can specify where begin and end values are important to us. Also, all the values between the range will be included bases on the steps we specify.

# %%
small_list = list(range(5))
subset_range = df.iloc[:, small_list] 
subset_range

# this is the same of df.loc[:, [0, 1, 2, 3, 4]]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# [17000 rows x 5 columns]

# %%
# specify the begin and end values
subset_begin_end = df.iloc[:, range(3, 7)]
subset_begin_end
# Out:
#        total_rooms  total_bedrooms  population  households
# 0           5612.0          1283.0      1015.0       472.0
# 1           7650.0          1901.0      1129.0       463.0
# 2            720.0           174.0       333.0       117.0
# 3           1501.0           337.0       515.0       226.0
# 4           1454.0           326.0       624.0       262.0
# ...            ...             ...         ...         ...
# 16995       2217.0           394.0       907.0       369.0
# 16996       2349.0           528.0      1194.0       465.0
# 16997       2677.0           531.0      1244.0       456.0
# 16998       2672.0           552.0      1298.0       478.0
# 16999       1820.0           300.0       806.0       270.0
#
# [17000 rows x 4 columns]

# %% [markdown]
# before I mentioned that range works based on the begin and end we specify and the steps. So, what this means?
#
# There is another parameter we can pass, that says how many steps we will do to pick up a column

# %%
subset_step = df.iloc[:, range(0, 7, 3)]
# this means we will take a column over 3 steps
subset_step
# Out:
#        longitude  total_rooms  households
# 0        -114.31       5612.0       472.0
# 1        -114.47       7650.0       463.0
# 2        -114.56        720.0       117.0
# 3        -114.57       1501.0       226.0
# 4        -114.57       1454.0       262.0
# ...          ...          ...         ...
# 16995    -124.26       2217.0       369.0
# 16996    -124.27       2349.0       465.0
# 16997    -124.30       2677.0       456.0
# 16998    -124.30       2672.0       478.0
# 16999    -124.35       1820.0       270.0
#
# [17000 rows x 3 columns]

# %% [markdown]
# # Slicing columns

# %%
slicing = df.iloc[:, : 3]
# takes the first 3 columns
slicing
# Out:
#        longitude  latitude  housing_median_age
# 0        -114.31     34.19                15.0
# 1        -114.47     34.40                19.0
# 2        -114.56     33.69                17.0
# 3        -114.57     33.64                14.0
# 4        -114.57     33.57                20.0
# ...          ...       ...                 ...
# 16995    -124.26     40.58                52.0
# 16996    -124.27     40.69                36.0
# 16997    -124.30     41.84                17.0
# 16998    -124.30     41.80                19.0
# 16999    -124.35     40.54                52.0
#
# [17000 rows x 3 columns]

# %%
slicing_all = df.iloc[:, 3 : ]
# takes all the columns except the 3 first
slicing_all
# Out:
#        total_rooms  total_bedrooms  ...  median_income  median_house_value
# 0           5612.0          1283.0  ...         1.4936             66900.0
# 1           7650.0          1901.0  ...         1.8200             80100.0
# 2            720.0           174.0  ...         1.6509             85700.0
# 3           1501.0           337.0  ...         3.1917             73400.0
# 4           1454.0           326.0  ...         1.9250             65500.0
# ...            ...             ...  ...            ...                 ...
# 16995       2217.0           394.0  ...         2.3571            111400.0
# 16996       2349.0           528.0  ...         2.5179             79000.0
# 16997       2677.0           531.0  ...         3.0313            103600.0
# 16998       2672.0           552.0  ...         1.9797             85800.0
# 16999       1820.0           300.0  ...         3.0147             94600.0
#
# [17000 rows x 6 columns]

# %%
slicing_last = df.iloc[:, : -3]
# all the columns except the last 3
slicing_last
# Out:
#        longitude  latitude  ...  total_bedrooms  population
# 0        -114.31     34.19  ...          1283.0      1015.0
# 1        -114.47     34.40  ...          1901.0      1129.0
# 2        -114.56     33.69  ...           174.0       333.0
# 3        -114.57     33.64  ...           337.0       515.0
# 4        -114.57     33.57  ...           326.0       624.0
# ...          ...       ...  ...             ...         ...
# 16995    -124.26     40.58  ...           394.0       907.0
# 16996    -124.27     40.69  ...           528.0      1194.0
# 16997    -124.30     41.84  ...           531.0      1244.0
# 16998    -124.30     41.80  ...           552.0      1298.0
# 16999    -124.35     40.54  ...           300.0       806.0
#
# [17000 rows x 6 columns]

# %%
slicing_end = df.iloc[:, -3 :]
# takes only the last 3 columns
slicing_end
# Out:
#        households  median_income  median_house_value
# 0           472.0         1.4936             66900.0
# 1           463.0         1.8200             80100.0
# 2           117.0         1.6509             85700.0
# 3           226.0         3.1917             73400.0
# 4           262.0         1.9250             65500.0
# ...           ...            ...                 ...
# 16995       369.0         2.3571            111400.0
# 16996       465.0         2.5179             79000.0
# 16997       456.0         3.0313            103600.0
# 16998       478.0         1.9797             85800.0
# 16999       270.0         3.0147             94600.0
#
# [17000 rows x 3 columns]

# %%
slicing_range = df.iloc[:, 2:5]
# copy of the column 2 to 5
# same as df.iloc[:, range(2, 5)]
slicing_range
# Out:
#        housing_median_age  total_rooms  total_bedrooms
# 0                    15.0       5612.0          1283.0
# 1                    19.0       7650.0          1901.0
# 2                    17.0        720.0           174.0
# 3                    14.0       1501.0           337.0
# 4                    20.0       1454.0           326.0
# ...                   ...          ...             ...
# 16995                52.0       2217.0           394.0
# 16996                36.0       2349.0           528.0
# 16997                17.0       2677.0           531.0
# 16998                19.0       2672.0           552.0
# 16999                52.0       1820.0           300.0
#
# [17000 rows x 3 columns]

# %%
slicing_steps = df.iloc[:, 0: 5: 2]
slicing_steps
# Out:
#        longitude  housing_median_age  total_bedrooms
# 0        -114.31                15.0          1283.0
# 1        -114.47                19.0          1901.0
# 2        -114.56                17.0           174.0
# 3        -114.57                14.0           337.0
# 4        -114.57                20.0           326.0
# ...          ...                 ...             ...
# 16995    -124.26                52.0           394.0
# 16996    -124.27                36.0           528.0
# 16997    -124.30                17.0           531.0
# 16998    -124.30                19.0           552.0
# 16999    -124.35                52.0           300.0
#
# [17000 rows x 3 columns]

# %% [markdown]
# ### Let's try out some slicing methods

# %%
df.head() #this is our original df
# Out:
#    longitude  latitude  ...  median_income  median_house_value
# 0    -114.31     34.19  ...         1.4936             66900.0
# 1    -114.47     34.40  ...         1.8200             80100.0
# 2    -114.56     33.69  ...         1.6509             85700.0
# 3    -114.57     33.64  ...         3.1917             73400.0
# 4    -114.57     33.57  ...         1.9250             65500.0
#
# [5 rows x 9 columns]

# %%
df.iloc[:, 0:5:]
# will take the first 5 columns, without jump
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# [17000 rows x 5 columns]

# %%
df.iloc[:, 0::2]
# from the first to last column, jumping 2
# Out:
#        longitude  housing_median_age  ...  households  median_house_value
# 0        -114.31                15.0  ...       472.0             66900.0
# 1        -114.47                19.0  ...       463.0             80100.0
# 2        -114.56                17.0  ...       117.0             85700.0
# 3        -114.57                14.0  ...       226.0             73400.0
# 4        -114.57                20.0  ...       262.0             65500.0
# ...          ...                 ...  ...         ...                 ...
# 16995    -124.26                52.0  ...       369.0            111400.0
# 16996    -124.27                36.0  ...       465.0             79000.0
# 16997    -124.30                17.0  ...       456.0            103600.0
# 16998    -124.30                19.0  ...       478.0             85800.0
# 16999    -124.35                52.0  ...       270.0             94600.0
#
# [17000 rows x 5 columns]

# %%
df.iloc[:, :5:2]
# the first to 5th column, jumping
# Out:
#        longitude  housing_median_age  total_bedrooms
# 0        -114.31                15.0          1283.0
# 1        -114.47                19.0          1901.0
# 2        -114.56                17.0           174.0
# 3        -114.57                14.0           337.0
# 4        -114.57                20.0           326.0
# ...          ...                 ...             ...
# 16995    -124.26                52.0           394.0
# 16996    -124.27                36.0           528.0
# 16997    -124.30                17.0           531.0
# 16998    -124.30                19.0           552.0
# 16999    -124.35                52.0           300.0
#
# [17000 rows x 3 columns]

# %%
df.iloc[:, ::2]
# first to last jumping 2
# Out:
#        longitude  housing_median_age  ...  households  median_house_value
# 0        -114.31                15.0  ...       472.0             66900.0
# 1        -114.47                19.0  ...       463.0             80100.0
# 2        -114.56                17.0  ...       117.0             85700.0
# 3        -114.57                14.0  ...       226.0             73400.0
# 4        -114.57                20.0  ...       262.0             65500.0
# ...          ...                 ...  ...         ...                 ...
# 16995    -124.26                52.0  ...       369.0            111400.0
# 16996    -124.27                36.0  ...       465.0             79000.0
# 16997    -124.30                17.0  ...       456.0            103600.0
# 16998    -124.30                19.0  ...       478.0             85800.0
# 16999    -124.35                52.0  ...       270.0             94600.0
#
# [17000 rows x 5 columns]

# %%
df.iloc[:, ::]
# create a copy og the inteirelly df
# Out:
#        longitude  latitude  ...  median_income  median_house_value
# 0        -114.31     34.19  ...         1.4936             66900.0
# 1        -114.47     34.40  ...         1.8200             80100.0
# 2        -114.56     33.69  ...         1.6509             85700.0
# 3        -114.57     33.64  ...         3.1917             73400.0
# 4        -114.57     33.57  ...         1.9250             65500.0
# ...          ...       ...  ...            ...                 ...
# 16995    -124.26     40.58  ...         2.3571            111400.0
# 16996    -124.27     40.69  ...         2.5179             79000.0
# 16997    -124.30     41.84  ...         3.0313            103600.0
# 16998    -124.30     41.80  ...         1.9797             85800.0
# 16999    -124.35     40.54  ...         3.0147             94600.0
#
# [17000 rows x 9 columns]

# %% [markdown]
# ## Subsetting rows and columns

# %%
df.loc[77, "total_rooms"]
# the row 77 at colum total_rooms
# this works as a matrix
# Out:
# 1672.0

# %%
df.iloc[88, 0]
# access row 88 at column 0
# Out:
# -115.57

# %% [markdown]
# ### Access multiple rows and columns

# %%
df.iloc[[0,88,11], [0, 4, 7]]
# first list represents the rows we want to access
# second list is the columns number (because we use iloc)
# Out:
#     longitude  total_bedrooms  median_income
# 0     -114.31          1283.0         1.4936
# 88    -115.57           301.0         1.9531
# 11    -114.60           483.0         1.6250

# %%
# to use loc, it'll work the same way, but now we pass the name of the columns
# first list: rows we want access
# second list: all the columns
df.loc[[0, 77, 1000], ["longitude", "total_bedrooms", "median_income"]]
# Out:
#       longitude  total_bedrooms  median_income
# 0       -114.31          1283.0         1.4936
# 77      -115.56           416.0         1.5987
# 1000    -117.10           658.0         3.2614

# %% [markdown]
# we can mix all we learn untill now: filter columns with range of rows, all rows for the columns...

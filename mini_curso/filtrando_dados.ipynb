# %%
import pandas as pd

# %%
df = pd.read_csv("./datasets/covid19_tweets.csv")

# %%
df.sample(5)
# mostra 5 linhas aleatorias
# Out:
#                  user_name             user_location  \
# 71388   Sir Simon McDonald                       NaN
# 120066             Zakiyya              South Africa
# 45774            Chris May           Little Rock, AR
# 131309        Kyle Delfing  Vernon, British Columbia
# 164126        Arizona Bats                       NaN
#
#                                          user_description  \
# 71388   Permanent Under-Secretary, Foreign & Commonwea...
# 120066  Head of Software Delivery & Operations at a Fi...
# 45774                               News anchor @KATVNews
# 131309  Entrepreneu/shareholder, #PPC EDA member NOS, ...
# 164126  Badass Teachers Association was created to giv...
#
#                user_created  user_followers  user_friends  user_favourites  \
# 71388   2015-07-28 08:52:32           29030           177              874
# 120066  2009-03-27 17:02:49            1523          2149            24586
# ...

# %%
df["hashtags"].unique()
# Out:
# array([nan, "['COVID19']", "['CoronaVirusUpdates', 'COVID19']", ...,
#        "['COVID19', 'coronavirus', 'TrumpVirus']",
#        "['COVID19', 'CloseTheSchools', 'KeepTheSchoolsClosed', 'KeepTeachersAlive', 'K12']",
#        "['nurses', 'COVID19', 'coronavirus', 'schools']"], dtype=object)

# %%
df.shape
# Out:
# (179108, 13)

# %%
df.info
# Out:
# <bound method DataFrame.info of                      user_name               user_location  \
# 0                       ᏉᎥ☻լꂅϮ                  astroworld
# 1                Tom Basile 🇺🇸                New York, NY
# 2              Time4fisticuffs            Pewee Valley, KY
# 3                  ethel mertz        Stuck in the Middle
# 4                     DIPR-J&K           Jammu and Kashmir
# ...                        ...                         ...
# 179103  AJIMATI AbdulRahman O.             Ilorin, Nigeria
# 179104                   Jason                     Ontario
# 179105             BEEHEMOTH ⏳                   🇨🇦 Canada
# 179106           Gary DelPonte               New York City
# 179107                 TUKY II  Aliwal North, South Africa
#
#                                          user_description  \
# 0       wednesday addams as a disney princess keepin i...
# 1       Husband, Father, Columnist & Commentator. Auth...
# ...

# %%
df.loc[df["user_location"].isna()]
# Out:
#                      user_name user_location  \
# 7               Derbyshire LPC           NaN
# 8            Prathamesh Bendre           NaN
# 10      Voice Of CBSE Students           NaN
# 16              ChennaiCityNow           NaN
# 18                  Dorian Aur           NaN
# ...                        ...           ...
# 179083           Auntie Kittie           NaN
# 179091             🦋  ROGUE  🦋           NaN
# 179092       claudia fernandez           NaN
# 179097               rainmaker           NaN
# 179098               John Geer           NaN
#
#                                          user_description  \
# 7                                                     NaN
# 8        A poet, reiki practitioner and a student of law.
# 10                                                    NaN
# 16      Individual tweeting about significant happenin...
# 18                                                    NaN
# ...                                                   ...
# ...

# %% [markdown]
# Nesse momento, podemos perceber que o DataFrame possui valores classificados como NaN
#
# algumas operações podem ser afetadas por tais valores, como plot, manipulação de string...
#
# Portanto, no processo de limpeza de dados, devemos sempre analisar se as demais informações dessas colunas são relevantes, ou se podemos simplesmente remover os dados por completo

# %%
df.loc[df["user_description"].isna()]
# Out:
#                      user_name  user_location user_description  \
# 7               Derbyshire LPC            NaN              NaN
# 10      Voice Of CBSE Students            NaN              NaN
# 18                  Dorian Aur            NaN              NaN
# 20           The Voice of GenX            NaN              NaN
# 30                      Ms Paz  United States              NaN
# ...                        ...            ...              ...
# 178978               Cody Vest            NaN              NaN
# 178988                   Shane        Ireland              NaN
# 179037            Carol London            NaN              NaN
# 179092       claudia fernandez            NaN              NaN
# 179097               rainmaker            NaN              NaN
#
#                user_created  user_followers  user_friends  user_favourites  \
# 7       2012-02-03 18:08:10             608           355               95
# ...

# %%
df.shape
# Out:
# (179108, 13)

# %% [markdown]
# o DataFrame possui no total 179108 linhas, se excluirmos todos os dados NaN, de ambas as colunas, estariamos excluindo um maximo de 47059 (desconsiderando que algumas linhas possam ter NaN em ambas colunas).

# %% [markdown]
# # Excluindo dados

# %%
df_exclui = df.dropna(subset=["user_description", "user_location"])

# %%
df_exclui.shape
# Out:
# (138352, 13)

# %%
df_exclui.loc[df_exclui["user_description"].isna()]
# Out:
# Empty DataFrame
# Columns: [user_name, user_location, user_description, user_created, user_followers, user_friends, user_favourites, user_verified, date, text, hashtags, source, is_retweet]
# Index: []

# %%
df_exclui.loc[df_exclui["user_location"].isna()]
# Out:
# Empty DataFrame
# Columns: [user_name, user_location, user_description, user_created, user_followers, user_friends, user_favourites, user_verified, date, text, hashtags, source, is_retweet]
# Index: []

# %%
df_exclui.loc[df_exclui["hashtags"].isna()]
# Out:
#                 user_name               user_location  \
# 0                  ᏉᎥ☻լꂅϮ                  astroworld
# 1           Tom Basile 🇺🇸                New York, NY
# 14         DailyaddaaNews                   New Delhi
# 19        Coronavirus Law                Florida, USA
# 21      APO Group English               #AFRICA #MENA
# ...                   ...                         ...
# 179085     3D Innovations            Honolulu, Hawaii
# 179090   Randy Richardson              Des Moines, IA
# 179096     laura l. sweet             Los Angeles, CA
# 179105        BEEHEMOTH ⏳                   🇨🇦 Canada
# 179107            TUKY II  Aliwal North, South Africa
#
#                                          user_description  \
# 0       wednesday addams as a disney princess keepin i...
# 1       Husband, Father, Columnist & Commentator. Auth...
# 14                       Breaking news alerts from India.
# 19                       COVID-19 Practice of Lechner Law
# ...

# %% [markdown]
# # Filtrando dados com valor

# %%
df["user_location"] = df["user_location"].fillna("")

# %%
df
# Out:
#                      user_name               user_location  \
# 0                       ᏉᎥ☻լꂅϮ                  astroworld
# 1                Tom Basile 🇺🇸                New York, NY
# 2              Time4fisticuffs            Pewee Valley, KY
# 3                  ethel mertz        Stuck in the Middle
# 4                     DIPR-J&K           Jammu and Kashmir
# ...                        ...                         ...
# 179103  AJIMATI AbdulRahman O.             Ilorin, Nigeria
# 179104                   Jason                     Ontario
# 179105             BEEHEMOTH ⏳                   🇨🇦 Canada
# 179106           Gary DelPonte               New York City
# 179107                 TUKY II  Aliwal North, South Africa
#
#                                          user_description  \
# 0       wednesday addams as a disney princess keepin i...
# 1       Husband, Father, Columnist & Commentator. Auth...
# 2       #Christian #Catholic #Conservative #Reagan #Re...
# ...

# %%
df.loc[df["user_location"].isna()]
# Out:
# Empty DataFrame
# Columns: [user_name, user_location, user_description, user_created, user_followers, user_friends, user_favourites, user_verified, date, text, hashtags, source, is_retweet]
# Index: []

# %%
df.loc[df["user_location"] == ""]
# Out:
#                      user_name user_location  \
# 7               Derbyshire LPC
# 8            Prathamesh Bendre
# 10      Voice Of CBSE Students
# 16              ChennaiCityNow
# 18                  Dorian Aur
# ...                        ...           ...
# 179083           Auntie Kittie
# 179091             🦋  ROGUE  🦋
# 179092       claudia fernandez
# 179097               rainmaker
# 179098               John Geer
#
#                                          user_description  \
# 7                                                     NaN
# 8        A poet, reiki practitioner and a student of law.
# 10                                                    NaN
# 16      Individual tweeting about significant happenin...
# 18                                                    NaN
# ...                                                   ...
# 179083  I'm the auntie you always wished you had.  If ...
# 179091  May all aching hearts find their way there thr...
# ...

# %%
df.loc[df["user_description"].isna()]
# Out:
#                      user_name  user_location user_description  \
# 7               Derbyshire LPC                             NaN
# 10      Voice Of CBSE Students                             NaN
# 18                  Dorian Aur                             NaN
# 20           The Voice of GenX                             NaN
# 30                      Ms Paz  United States              NaN
# ...                        ...            ...              ...
# 178978               Cody Vest                             NaN
# 178988                   Shane        Ireland              NaN
# 179037            Carol London                             NaN
# 179092       claudia fernandez                             NaN
# 179097               rainmaker                             NaN
#
#                user_created  user_followers  user_friends  user_favourites  \
# 7       2012-02-03 18:08:10             608           355               95
# ...

# %%
# podemos usar qualquer valor como filtro

df["user_description"] = df["user_description"].fillna("oi")

# %%
df_depois = df.loc[df["user_description"].str.contains("oi")]

# %%
df_depois
# Out:
#                                 user_name      user_location  \
# 7                          Derbyshire LPC
# 10                 Voice Of CBSE Students
# 18                             Dorian Aur
# 20                      The Voice of GenX
# 27             beatnikgeek the soothsayer      Manhattan, NY
# ...                                   ...                ...
# 179058                          Don Stand  Where my heart is
# 179061  EpiTrace© Sentinel Solutions Inc.          Canada 🇨🇦
# 179063               IL State Med Society
# 179092                  claudia fernandez
# 179097                          rainmaker
#
#                                          user_description  \
# 7                                                      oi
# 10                                                     oi
# 18                                                     oi
# 20                                                     oi
# 27      These days, I expose colonizers & exploits @ t...
# ...

# %%
df
# Out:
#                      user_name               user_location  \
# 0                       ᏉᎥ☻լꂅϮ                  astroworld
# 1                Tom Basile 🇺🇸                New York, NY
# 2              Time4fisticuffs            Pewee Valley, KY
# 3                  ethel mertz        Stuck in the Middle
# 4                     DIPR-J&K           Jammu and Kashmir
# ...                        ...                         ...
# 179103  AJIMATI AbdulRahman O.             Ilorin, Nigeria
# 179104                   Jason                     Ontario
# 179105             BEEHEMOTH ⏳                   🇨🇦 Canada
# 179106           Gary DelPonte               New York City
# 179107                 TUKY II  Aliwal North, South Africa
#
#                                          user_description  \
# 0       wednesday addams as a disney princess keepin i...
# 1       Husband, Father, Columnist & Commentator. Auth...
# 2       #Christian #Catholic #Conservative #Reagan #Re...
# ...
